# %%
from HARK.unstrucinterp import UnstrucInterp

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 11)
x, y = np.meshgrid(x, x, indexing="ij")
z = x**2 + y**2
z[5,5] = np.nan

# %%
interp = UnstrucInterp(z, [x,y], method="cubic")

# %%
interp(5,5)
# Out:
# array(50.12173504)
